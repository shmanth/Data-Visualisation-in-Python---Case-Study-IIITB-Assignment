# %% [markdown]
# <a href="https://colab.research.google.com/github/shmanth/Data-Visualisation-in-Python---Case-Study-IIITB-Assignment/blob/master/Data_Visualisation_in_Python_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Playstore Case Study

# %% [markdown]
# In this module you’ll be learning data visualisation with the help of a case study. This will enable you to understand how visualisation aids you in solving business problems.

# %% [markdown]
# **Problem Statement**
#
# The team at Google Play Store wants to develop a feature that would enable them to boost visibility for the most promising apps. Now, this analysis would require a preliminary understanding of the features that define a well-performing app. You can ask questions like:
# - Does a higher size or price necessarily mean that an app would perform better than the other apps?
# - Or does a higher number of installs give a clear picture of which app would have a better rating than others?

# %% [markdown]
# ### Session 1 - Introduction to Data Visualisation

# %%
#import the libraries

import numpy as np, pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read the dataset and check the first five rows
inp0 = pd.read_csv("/content/drive/MyDrive/Data_colab_practice_august_2023/googleplaystore_v2.csv")
inp0.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type Price Content Rating  \
# 0     159  19000.0      10,000+  Free     0       Everyone
# 1     967  14000.0     500,000+  Free     0       Everyone
# 2   87510   8700.0   5,000,000+  Free     0       Everyone
# 3  215644  25000.0  50,000,000+  Free     0           Teen
# 4     967   2800.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Check the shape of the dataframe
inp0.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Data Handling and Cleaning

# %% [markdown]
# The first few steps involve making sure that there are no __missing values__ or __incorrect data types__ before we proceed to the analysis stage. These aforementioned problems are handled as follows:
#
#  - For Missing Values: Some common techniques to treat this issue are
#     - Dropping the rows containing the missing values
#     - Imputing the missing values
#     - Keep the missing values if they don't affect the analysis
#
#
#  - Incorrect Data Types:
#     - Clean certain values
#     - Clean and convert an entire column

# %%
#Check the datatypes of all the columns of the dataframe
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Missing Value Treatment

# %%
#Check the number of null values in the columns
inp0.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Handling missing values for rating
#  - Ratings is the target variable
#  - drop the records

# %%
inp0["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
#Drop the rows having null values in the Rating field

gplay= inp0[~inp0['Rating'].isnull()]
#Check the shape of the dataframe
gplay.shape
# Out:
# (9367, 13)

# %%
# Check the number of nulls in the Rating field again to cross-verify
gplay.Rating.isnull().sum()
# Out:
# 0

# %%
#Question
#Check the number of nulls in the dataframe again and find the total number of null values
gplay.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
#Inspect the nulls in the Android Version column
gplay[gplay["Android Ver"].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews          Size Installs  Type     Price Content Rating  \
# 4453      230  11000.000000   1,000+  Paid     $1.49       Everyone
# 4490      189   2100.000000  10,000+  Free         0       Everyone
# 10472    3.0M  21516.529524     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#Drop the row having shifted values
gplay= gplay[~(gplay["Android Ver"].isnull() & (gplay["Rating"] == 19.0))]
#Check the nulls againin Android version column to cross-verify
gplay["Android Ver"].isnull().sum()
# Out:
# 2

# %% [markdown]
# Imputing Missing Values
#
# - For numerical variables use mean and median
# - For categorical variables use mode

# %%
#Check the most common value in the Android version column
gplay["Android Ver"].mode()[0]
# Out:
# '4.1 and up'

# %%
gplay["Android Ver"].value_counts()
# Out:
# 4.1 and up            2059
# Varies with device    1319
# 4.0.3 and up          1240
# 4.0 and up            1131
# 4.4 and up             875
# 2.3 and up             582
# 5.0 and up             535
# 4.2 and up             338
# 2.3.3 and up           240
# 3.0 and up             211
# 2.2 and up             208
# 4.3 and up             207
# 2.1 and up             113
# 1.6 and up              87
# 6.0 and up              48
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              18
# 1.5 and up              16
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              6
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# Name: Android Ver, dtype: int64

# %%
#Fill up the nulls in the Android Version column with the above value
gplay["Android Ver"]=gplay["Android Ver"].fillna(gplay["Android Ver"].mode()[0])

# %%
#Check the nulls in the Android version column again to cross-verify
gplay["Android Ver"].value_counts()
# Out:
# 4.1 and up            2061
# Varies with device    1319
# 4.0.3 and up          1240
# 4.0 and up            1131
# 4.4 and up             875
# 2.3 and up             582
# 5.0 and up             535
# 4.2 and up             338
# 2.3.3 and up           240
# 3.0 and up             211
# 2.2 and up             208
# 4.3 and up             207
# 2.1 and up             113
# 1.6 and up              87
# 6.0 and up              48
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              18
# 1.5 and up              16
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              6
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# Name: Android Ver, dtype: int64

# %%
#Check the nulls in the entire dataframe again
gplay.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       0
# dtype: int64

# %%
#Check the most common value in the Current version column
gplay["Current Ver"].mode()
# Out:
# 0    Varies with device
# Name: Current Ver, dtype: object

# %%
gplay["Current Ver"].value_counts()
# Out:
# Varies with device    1415
# 1.0                    458
# 1.1                    195
# 1.2                    126
# 1.3                    120
#                       ...
# 2.9.10                   1
# 3.18.5                   1
# 1.3.A.2.9                1
# 9.9.1.1910               1
# 0.3.4                    1
# Name: Current Ver, Length: 2638, dtype: int64

# %%
#Replace the nulls in the Current version column with the above value
gplay["Current Ver"]=gplay["Current Ver"].fillna(gplay["Current Ver"].mode()[0])

# %%
# Question : Check the most common value in the Current version column again
gplay["Current Ver"].value_counts()
# Out:
# Varies with device    1419
# 1.0                    458
# 1.1                    195
# 1.2                    126
# 1.3                    120
#                       ...
# 2.9.10                   1
# 3.18.5                   1
# 1.3.A.2.9                1
# 9.9.1.1910               1
# 0.3.4                    1
# Name: Current Ver, Length: 2638, dtype: int64

# %% [markdown]
# #### Handling Incorrect Data Types

# %%
#Check the datatypes of all the columns
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
gplay["Android Ver"]
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10834            4.1 and up
# 10836            4.1 and up
# 10837            4.1 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 9366, dtype: object

# %%
#Question - Try calculating the average price of all apps having the Android version as "4.1 and up"

def avg_price(x):
  average_price= gplay["Price"].mean()
  return average_price

# %%
#avg_price(gplay[gplay["Android Ver"] == "4.1 and up"])

# %%
#Analyse the Price column to check the issue

gplay["Price"].value_counts()
# Out:
# 0          8719
# $2.99       114
# $0.99       107
# $4.99        70
# $1.99        59
#            ...
# $1.29         1
# $299.99       1
# $379.99       1
# $37.99        1
# $1.20         1
# Name: Price, Length: 73, dtype: int64

# %%
gplay["Price"].isnull().sum()
# Out:
# 0

# %%
#Write the function to make the changes

gplay["Price"]= gplay["Price"].apply(lambda x: 0 if x=='0' else float(x[1:]))

# %%
#Verify the dtype of Price once again
gplay["Price"].dtype
# Out:
# dtype('float64')

# %%
gplay["Price"].value_counts()
# Out:
# 0.00      8719
# 2.99       114
# 0.99       107
# 4.99        70
# 1.99        59
#           ...
# 1.29         1
# 299.99       1
# 379.99       1
# 37.99        1
# 1.20         1
# Name: Price, Length: 73, dtype: int64

# %%
avg_price(gplay[gplay["Android Ver"] == "4.1 and up"])
# Out:
# 0.9609278240444159

# %%
#Analyse the Reviews column
gplay["Reviews"].value_counts()
# Out:
# 2         83
# 3         78
# 4         74
# 5         74
# 1         67
#           ..
# 49657      1
# 41420      1
# 7146       1
# 44706      1
# 398307     1
# Name: Reviews, Length: 5992, dtype: int64

# %%
gplay["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10834         7
# 10836        38
# 10837         4
# 10839       114
# 10840    398307
# Name: Reviews, Length: 9366, dtype: object

# %%
#Change the dtype of this column
gplay["Reviews"]= gplay["Reviews"].astype("int32")

#Check the quantitative spread of this dataframe

gplay["Reviews"].describe()
# Out:
# count    9.366000e+03
# mean     5.140498e+05
# std      3.144042e+06
# min      1.000000e+00
# 25%      1.862500e+02
# 50%      5.930500e+03
# 75%      8.153275e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
#Analyse the Installs Column

gplay["Installs"].value_counts()
# Out:
# 1,000,000+        1577
# 10,000,000+       1252
# 100,000+          1150
# 10,000+           1010
# 5,000,000+         752
# 1,000+             713
# 500,000+           538
# 50,000+            467
# 5,000+             432
# 100,000,000+       409
# 100+               309
# 50,000,000+        289
# 500+               201
# 500,000,000+        72
# 10+                 69
# 1,000,000,000+      58
# 50+                 56
# 5+                   9
# 1+                   3
# Name: Installs, dtype: int64

# %%
gplay["Installs"]= gplay["Installs"].str.replace(',' , "")

# %%
#Question Clean the Installs Column and find the approximate number of apps at the 50th percentile.
gplay["Installs"]= gplay["Installs"].apply(lambda x: float(x[:-1]))

# %%
gplay["Installs"].value_counts()
# Out:
# 1.000000e+06    1577
# 1.000000e+07    1252
# 1.000000e+05    1150
# 1.000000e+04    1010
# 5.000000e+06     752
# 1.000000e+03     713
# 5.000000e+05     538
# 5.000000e+04     467
# 5.000000e+03     432
# 1.000000e+08     409
# 1.000000e+02     309
# 5.000000e+07     289
# 5.000000e+02     201
# 5.000000e+08      72
# 1.000000e+01      69
# 1.000000e+09      58
# 5.000000e+01      56
# 5.000000e+00       9
# 1.000000e+00       3
# Name: Installs, dtype: int64

# %%
gplay["Installs"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Sanity Checks

# %% [markdown]
# The data that we have needs to make sense and therefore you can perform certain sanity checks on them to ensure they are factually correct as well. Some sanity checks can be:
#
# - Rating is between 1 and 5 for all the apps.
# - Number of Reviews is less than or equal to the number of Installs.
# - Free Apps shouldn’t have a price greater than 0.

# %%
gplay["Rating"].dtype
# Out:
# dtype('float64')

# %%
# check rating column
gplay["Rating"].describe()
# Out:
# count    9366.000000
# mean        4.191757
# std         0.515219
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
#Perform the sanity checks on the Reviews column
gplay[(gplay["Reviews"]>gplay["Installs"])]
# Out:
#                                  App   Category  Rating  Reviews  \
# 2454             KBA-EZ Health Guide    MEDICAL     5.0        4
# 4663   Alarmy (Sleep If U Can) - Pro  LIFESTYLE     4.8    10249
# 5917                        Ra Ga Ba       GAME     5.0        2
# 6700                Brick Breaker BR       GAME     5.0        7
# 7402            Trovami se ci riesci       GAME     5.0       11
# 8591                         DN Blog     SOCIAL     5.0       20
# 10697                        Mu.F.O.       GAME     5.0        2
#
#                Size  Installs  Type  Price Content Rating     Genres  \
# 2454   25000.000000       1.0  Free   0.00       Everyone    Medical
# 4663   21516.529524   10000.0  Paid   2.49       Everyone  Lifestyle
# 5917   20000.000000       1.0  Paid   1.49       Everyone     Arcade
# 6700   19000.000000       5.0  Free   0.00       Everyone     Arcade
# 7402    6100.000000      10.0  Free   0.00       Everyone     Arcade
# ...

# %%
gplay=gplay[~(gplay["Reviews"]>gplay["Installs"])]

# %%
gplay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9359 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9359 non-null   object
#  1   Category        9359 non-null   object
#  2   Rating          9359 non-null   float64
#  3   Reviews         9359 non-null   int32
#  4   Size            9359 non-null   float64
#  5   Installs        9359 non-null   float64
#  6   Type            9359 non-null   object
#  7   Price           9359 non-null   float64
#  8   Content Rating  9359 non-null   object
#  9   Genres          9359 non-null   object
#  10  Last Updated    9359 non-null   object
#  11  Current Ver     9359 non-null   object
#  12  Android Ver     9359 non-null   object
# dtypes: float64(4), int32(1), object(8)
# memory usage: 987.1+ KB

# %%
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000.0  Free    0.0       Everyone
# 1      967  14000.0    500000.0  Free    0.0       Everyone
# 2    87510   8700.0   5000000.0  Free    0.0       Everyone
# 3   215644  25000.0  50000000.0  Free    0.0           Teen
# 4      967   2800.0    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#perform the sanity checks on prices of free apps
gplay[(gplay["Type"] == "Free") & (gplay["Price"] != 0)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# #### Outliers Analysis Using Boxplot

# %% [markdown]
# Now you need to start identifying and removing extreme values or __outliers__ from our dataset. These values can tilt our analysis and often provide us with a biased perspective of the data available. This is where you’ll start utilising visualisation to achieve your tasks. And the best visualisation to use here would be the box plot. Boxplots are one of the best ways of analysing the spread of a numeric variable
#
#
# Using a box plot you can identify the outliers as follows:

# %% [markdown]
# ![BoxPlots to Identify Outliers](images\Boxplot.png)

# %% [markdown]
# - Outliers in data can arise due to genuine reasons or because of dubious entries. In the latter case, you should go ahead and remove such entries immediately. Use a boxplot to observe, analyse and remove them.
# - In the former case, you should determine whether or not removing them would add value to your analysis procedure.

# %% [markdown]
# - You can create a box plot directly from pandas dataframe or the matplotlib way as you learnt in the previous session. Check out their official documentation here:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html
#    - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
#import the plotting libraries

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Create a box plot for the price column
plt.boxplot(gplay["Price"])
plt.show()

# %%
#Check the apps with price more than 200
gplay[gplay["Price"]>200]
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 4197          most expensive app (H)     FAMILY     4.3        6   1500.0
# 4362                      💎 I'm rich  LIFESTYLE     3.8      718  26000.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7300.0
# 5351                       I am rich  LIFESTYLE     3.8     3547   1800.0
# 5354                  I am Rich Plus     FAMILY     4.0      856   8700.0
# 5355                   I am rich VIP  LIFESTYLE     3.8      411   2600.0
# 5356               I Am Rich Premium    FINANCE     4.1     1867   4700.0
# 5357             I am extremely Rich  LIFESTYLE     2.9       41   2900.0
# 5358                      I am Rich!    FINANCE     3.8       93  22000.0
# 5359              I am rich(premium)    FINANCE     3.5      472    965.0
# 5362                   I Am Rich Pro     FAMILY     4.4      201   2700.0
# 5364  I am rich (Most expensive app)    FINANCE     4.1      129   2700.0
# ...

# %%
#Clean the Price column
gplay= gplay[~(gplay["Price"]>200)]

# %%
# verify
plt.boxplot(gplay["Price"])
plt.show()

# %%
gplay["Price"].value_counts()
# Out:
# 0.00     8715
# 2.99      114
# 0.99      106
# 4.99       70
# 1.99       59
#          ...
# 1.29        1
# 37.99       1
# 18.99       1
# 8.49        1
# 1.20        1
# Name: Price, Length: 68, dtype: int64

# %%
#Create a box plot for paid apps
gplay[gplay["Price"]>0].Price.plot.box()
# Out:
# <Axes: >

# %%
#Check the apps with price more than 30
gplay[gplay["Price"]>30]
# Out:
#                             App   Category  Rating  Reviews     Size  \
# 2253  Vargo Anesthesia Mega App    MEDICAL     4.6       92  32000.0
# 2301    A Manual of Acupuncture    MEDICAL     3.5      214  68000.0
# 2365  Vargo Anesthesia Mega App    MEDICAL     4.6       92  32000.0
# 2402    A Manual of Acupuncture    MEDICAL     3.5      214  68000.0
# 2414               LTC AS Legal    MEDICAL     4.0        6   1300.0
# 5360           I am Rich Person  LIFESTYLE     4.2      134   1800.0
#
#       Installs  Type  Price Content Rating     Genres     Last Updated  \
# 2253    1000.0  Paid  79.99       Everyone    Medical    June 18, 2018
# 2301    1000.0  Paid  33.99       Everyone    Medical  October 2, 2017
# 2365    1000.0  Paid  79.99       Everyone    Medical    June 18, 2018
# 2402    1000.0  Paid  33.99       Everyone    Medical  October 2, 2017
# 2414     100.0  Paid  39.99       Everyone    Medical    April 4, 2018
# ...

# %%
gplay["Price"].describe()
# Out:
# count    9344.000000
# mean        0.334463
# std         2.169925
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        79.990000
# Name: Price, dtype: float64

# %%
#Clean the Price column again
gplay=gplay[gplay["Price"]<=30]
gplay.shape
# Out:
# (9338, 13)

# %% [markdown]
# ### Histograms
#
# Histograms can also be used in conjuction with boxplots for data cleaning and data handling purposes. You can use it to check the spread of a numeric variable. Histograms generally work by bucketing the entire range of values that a particular variable takes to specific __bins__. After that, it uses vertical bars to denote the total number of records in a specific bin, which is also known as its __frequency__.

# %% [markdown]
# ![Histogram](images\Histogram.png)

# %% [markdown]
# You can adjust the number of bins to improve its granularity

# %% [markdown]
# ![Bins change](images\Granular.png)

# %% [markdown]
# You'll be using plt.hist() to plot a histogram. Check out its official documentation:https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html

# %%
#Create a histogram of the Reviews
plt.hist(gplay["Reviews"], bins=10)
plt.show()

# %%
#Create a boxplot of the Reviews column
plt.boxplot(gplay["Reviews"])
plt.show()

# %%
#Check records with 1 million reviews
gplay[gplay["Reviews"]>1000000]
# Out:
#                                           App             Category  Rating  \
# 139                      Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 152                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 189                               Uber Driver             BUSINESS     4.4
# 194    OfficeSuite : Free Office + PDF Editor             BUSINESS     4.3
# 201                    Facebook Pages Manager             BUSINESS     4.0
# ...                                       ...                  ...     ...
# 10190                         Fallout Shelter               FAMILY     4.6
# 10200                  Facebook Pages Manager             BUSINESS     4.0
# 10327                        Garena Free Fire                 GAME     4.5
# 10636                      FRONTLINE COMMANDO                 GAME     4.4
# 10707          Photo Editor Collage Maker Pro          PHOTOGRAPHY     4.5
#
# ...

# %%
#Drop the above records

gplay=gplay[~(gplay["Reviews"]>1000000)]

# %%
gplay.Reviews.value_counts()
# Out:
# 2         81
# 3         78
# 5         74
# 4         73
# 1         67
#           ..
# 97684      1
# 9653       1
# 58675      1
# 287250     1
# 398307     1
# Name: Reviews, Length: 5349, dtype: int64

# %%
#Question - Create a histogram again and check the peaks
plt.hist(gplay["Reviews"])
plt.show()

# %%
#Question - Create a box plot for the Installs column and report back the IQR
plt.boxplot(gplay["Installs"])
plt.show()

# %%
gplay.describe()
# Out:
#             Rating        Reviews           Size      Installs        Price
# count  8634.000000    8634.000000    8634.000000  8.634000e+03  8634.000000
# mean      4.172492   68383.348853   21636.459060  4.288536e+06     0.324913
# std       0.528913  156335.806417   20663.668474  2.864650e+07     1.731362
# min       1.000000       1.000000       8.500000  5.000000e+00     0.000000
# 25%       4.000000     143.250000    6000.000000  1.000000e+04     0.000000
# 50%       4.300000    3641.000000   18000.000000  1.000000e+05     0.000000
# 75%       4.500000   46070.500000   26000.000000  1.000000e+06     0.000000
# max       5.000000  995002.000000  100000.000000  1.000000e+09    29.990000

# %%
#Question - CLean the Installs by removing all the apps having more than or equal to 100 million installs
gplay= gplay[gplay["Installs"]<=100000000]

# %%
gplay["Installs"].value_counts()
# Out:
# 1000000.0      1577
# 10000000.0     1177
# 100000.0       1149
# 10000.0        1004
# 5000000.0       752
# 1000.0          704
# 500000.0        538
# 50000.0         466
# 5000.0          429
# 100.0           307
# 500.0           201
# 50000000.0      138
# 10.0             67
# 50.0             56
# 100000000.0      51
# 5.0               8
# Name: Installs, dtype: int64

# %%
gplay["Installs"].describe()
# Out:
# count    8.624000e+03
# mean     3.423843e+06
# std      1.017148e+07
# min      5.000000e+00
# 25%      1.000000e+04
# 50%      1.000000e+05
# 75%      1.000000e+06
# max      1.000000e+08
# Name: Installs, dtype: float64

# %%
#Plot a histogram for Size as well.
plt.hist(gplay["Installs"])
plt.show()

# %%
#Question - Create a boxplot for the Size column and report back the median value
plt.boxplot(gplay["Size"])
plt.show()

# %% [markdown]
# ### Session 2 - Data Visualisation with Seaborn

# %% [markdown]
# Seaborn is Python library to create statistical graphs easily. It is built on top of matplotlib and closely integrated with pandas.
#
# _Functionalities of Seaborn_ :
#
# - Dataset oriented API
# - Analysing univariate and bivariate distributions
# - Automatic estimation and plotting of  linear regression models
# - Convenient views for complex datasets
# - Concise control over style
# - Colour palettes

# %%
#import the necessary libraries
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Distribution Plots

# %% [markdown]
# A distribution plot is pretty similar to the histogram functionality in matplotlib. Instead of a frequency plot, it plots an approximate probability density for that rating bucket. And the curve (or the __KDE__) that gets drawn over the distribution is the approximate probability density curve.
#
# The following is an example of a distribution plot. Notice that now instead of frequency on the left axis, it has the density for each bin or bucket.

# %% [markdown]
# ![Distplot](images\Distplot.png)

# %% [markdown]
# You'll be using sns.distplot for plotting a distribution plot. Check out its official documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
#Create a distribution plot for rating
sns.distplot(gplay["Rating"])
plt.title("Distribution plot of Rating")
plt.show()

# %%
#Change the number of bins

sns.distplot(gplay["Rating"], bins=39)
plt.show()

# %%
#Change the colour of bins to green
sns.distplot(gplay["Rating"], color="b", bins=20)
plt.show()

# %%
#Apply matplotlib functionalities
sns.distplot(gplay["Rating"], color="b", bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %% [markdown]
# #### Styling Options
#
# One of the biggest advantages of using Seaborn is that you can retain its aesthetic properties and also the Matplotlib functionalities to perform additional customisations. Before we continue with our case study analysis, let’s study some styling options that are available in Seaborn.

# %% [markdown]
# -  Check out the official documentation:https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
#Check all the styling options
# ?sns.set_style

# %%
#Change the number of bins to 20
sns.set_style("whitegrid")
sns.distplot(gplay["Rating"], color="b", bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
sns.set_style("darkgrid")
sns.distplot(gplay["Rating"], color="b", bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
sns.set_style("dark")
sns.distplot(gplay["Rating"], color="b", bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("dark_background")

# %%
sns.distplot(gplay["Rating"],  bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
plt.style.use("tableau-colorblind10")

# %%
sns.distplot(gplay["Rating"], bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
plt.style.use("ggplot")

# %%
sns.distplot(gplay["Rating"], bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %%
plt.style.use("default")

# %%
sns.distplot(gplay["Rating"], bins=20)
plt.title("Distribution of app ratings", fontsize=12)
plt.show()

# %% [markdown]
# #### Pie-Chart and Bar Chart

# %% [markdown]
# For analysing how a numeric variable changes across several categories of a categorical variable you utilise either a pie chart or a box plot

# %% [markdown]
# For example, if you want to visualise the responses of a marketing campaign, you can use the following views:

# %% [markdown]
# ![PieChart](images\pie.png)

# %% [markdown]
# ![barChart](images\bar.png)

# %% [markdown]
# - You'll be using the pandas method of plotting both a pie chart and a bar chart. Check out their official documentations:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html

# %%
gplay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8624 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8624 non-null   object
#  1   Category        8624 non-null   object
#  2   Rating          8624 non-null   float64
#  3   Reviews         8624 non-null   int32
#  4   Size            8624 non-null   float64
#  5   Installs        8624 non-null   float64
#  6   Type            8624 non-null   object
#  7   Price           8624 non-null   float64
#  8   Content Rating  8624 non-null   object
#  9   Genres          8624 non-null   object
#  10  Last Updated    8624 non-null   object
#  11  Current Ver     8624 non-null   object
#  12  Android Ver     8624 non-null   object
# dtypes: float64(4), int32(1), object(8)
# memory usage: 909.6+ KB

# %%
#Analyse the Content Rating column
gplay["Content Rating"].value_counts()
# Out:
# Everyone           6938
# Teen                928
# Mature 17+          417
# Everyone 10+        337
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
#Remove the rows with values which are less represented
gplay=gplay[~(gplay["Content Rating"].isin(["Adults only 18+","Unrated"]))]

# %%
gplay["Content Rating"].value_counts()
# Out:
# Everyone        6938
# Teen             928
# Mature 17+       417
# Everyone 10+     337
# Name: Content Rating, dtype: int64

# %%
gplay["Content Rating"].shape
# Out:
# (8620,)

# %%
#Reset the index
gplay.reset_index(inplace=True,drop= True)

# %%
#Check the apps belonging to different categories of Content Rating
gplay[gplay["Content Rating"]=="Teen"]
# Out:
#                                                 App             Category  \
# 3                             Sketch - Draw & Paint       ART_AND_DESIGN
# 12                   Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 33                                  I Creative Idea       ART_AND_DESIGN
# 71    Android Auto - Maps, Media, Messaging & Voice    AUTO_AND_VEHICLES
# 111   Selfie Camera Photo Editor & Filter & Sticker               BEAUTY
# ...                                             ...                  ...
# 8597                   Fatal Raid - No.1 Mobile FPS                 GAME
# 8598                                   Poker Pro.Fr                 GAME
# 8603                           FR: My Secret Pets!                FAMILY
# 8606                                      Fanfic-FR  BOOKS_AND_REFERENCE
# 8607                                Fr. Daoud Lamei               FAMILY
#
#       Rating  Reviews     Size    Installs  Type  Price Content Rating  \
# ...

# %%
gplay[gplay["Content Rating"]=="Mature 17+"]
# Out:
#                                                     App             Category  \
# 127                      Dresses Ideas & Fashions +3000               BEAUTY
# 156                                   Read books online  BOOKS_AND_REFERENCE
# 160                                             Flybook  BOOKS_AND_REFERENCE
# 283                    MangaToon - Comics updated Daily               COMICS
# 284                Manga Net – Best Online Manga Reader               COMICS
# ...                                                 ...                  ...
# 8531  Frontline Terrorist Battle Shoot: Free FPS Sho...                 GAME
# 8567                    Chat For Strangers - Video Chat               SOCIAL
# 8580       Modern Counter Terror Attack – Shooting Game                 GAME
# 8608          Frim: get new friends on local chat rooms               SOCIAL
# 8618                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
#Plot a pie chart
gplay["Content Rating"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Content Rating'>

# %%
#Plot a bar chart
gplay["Content Rating"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#Question - Plot a bar plot for checking the 4th highest Android version type
gplay["Android Ver"].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# #### Scatter Plots

# %% [markdown]
# Scatterplots are perhaps one of the most commonly used as well one of the most powerful visualisations you can use in the field of machine learning. They are pretty crucial in revealing relationships between the data points and you can generally deduce some sort of trends in the data with the help of a scatter plot.

# %% [markdown]
# ![Scatterplot](images\scatter.png)

# %% [markdown]
# - They're pretty useful in regression problems to check whether a linear trend exists in the data or not. For example, in the image below, creating a linear model in the first case makes far more sense since a clear straight line trend is visible.

# %% [markdown]
# ![Scatterplot-Reg](images\regression3.png)

# %% [markdown]
# - Also, they help in observing __naturally occuring clusters__. In the following image, the marks of students in Maths and Biology has been plotted.You can clearly group the students to 4 clusters now. Cluster 1 are students who score very well in Biology but very poorly in Maths, Cluster 2 are students who score equally well in both the subjects and so on.

# %% [markdown]
# ![Scatter-Clusters](images\Clusters.png)

# %% [markdown]
# **Note**: You'll be studying about both Regression and Clustering in greater detail in the machine learning modules

# %% [markdown]
# You'll be using **sns.jointplot()** for creating a scatter plot. Check out its documentation:
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
###Size vs Rating

##Plot a scatter-plot in the matplotlib way between Size and Rating
plt.scatter(gplay.Size, gplay.Rating)
plt.show()

# %%
sns.set_style("white")

# %%
# ?sns.jointplot

# %%
### Plot the same thing now using a jointplot
sns.jointplot(x=gplay.Size, y=gplay.Rating)
plt.show()

# %%
## Plot a jointplot for Price and Rating
sns.jointplot(x=gplay.Price, y= gplay.Rating)
plt.show()

# %% [markdown]
# **Reg Plots**
#
# - These are an extension to the jointplots, where a regression line is added to the view

# %%
sns.jointplot(x= gplay.Size, y= gplay.Rating, kind = 'kde',color = 'g')
plt.show()

# %%
##Plot a reg plot for Price and Rating and observe the trend
sns.jointplot(x=gplay.Price, y=gplay.Rating, kind="reg")

# %%
gplay.Price.value_counts()
# Out:
# 0.00     7999
# 2.99      114
# 0.99      106
# 4.99       70
# 1.99       59
#          ...
# 1.29        1
# 18.99       1
# 8.49        1
# 1.75        1
# 1.20        1
# Name: Price, Length: 64, dtype: int64

# %%
gplay.Type.value_counts()
# Out:
# Free    7999
# Paid     621
# Name: Type, dtype: int64

# %%
## Question - Plot a reg plot for Price and Rating again for only the paid apps.
gplay
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 8615                                      FR Calculator               FAMILY
# 8616                                   Sya9a Maroc - FR               FAMILY
# 8617                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 8618                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 8619      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# **Pair Plots**

# %% [markdown]
#  - When you have several numeric variables, making multiple scatter plots becomes rather tedious. Therefore, a pair plot visualisation is preferred where all the scatter plots are in a single view in the form of a matrix
#  - For the non-diagonal views, it plots a **scatter plot** between 2 numeric variables
#  - For the diagonal views, it plots a **histogram**

# %% [markdown]
# Pair Plots help in identifying the trends between a target variable and the predictor variables pretty quickly. For example, say you want to predict how your company’s profits are affected by three different factors. In order to choose which you created a pair plot containing profits and the three different factors as the variables. Here are the scatterplots of profits vs the three variables that you obtained from the pair plot.

# %% [markdown]
# ![Pairplots](images\pairplots2.png)

# %% [markdown]
# It is clearly visible that the left-most factor is the most prominently related to the profits, given how linearly scattered the points are and how randomly scattered the rest two factors are.

# %% [markdown]
# You'll be using **sns.pairplot()** for this visualisation. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
# ?sns.pairplot

# %%
## Create a pair plot for Reviews, Size, Price and Rating
sns.pairplot(gplay[["Reviews", "Size", "Price", "Rating"]])
plt.show()

# %% [markdown]
# **Bar Charts Revisited**

# %% [markdown]
# - Here, you'll be using bar charts once again, this time using the **sns.barplot()** function. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.barplot.html
# - You can modify the **estimator** parameter to change the aggregation value of your barplot

# %%
gplay["Rating"].value_counts()
# Out:
# 4.3    946
# 4.4    931
# 4.2    896
# 4.5    890
# 4.6    700
# 4.1    692
# 4.0    551
# 4.7    455
# 3.9    381
# 3.8    297
# 5.0    268
# 3.7    236
# 4.8    226
# 3.6    172
# 3.5    160
# 3.4    128
# 3.3    102
# 4.9     87
# 3.0     83
# 3.1     69
# 3.2     64
# 2.9     44
# 2.8     42
# 2.7     25
# 2.6     25
# 2.5     21
# 2.3     20
# 2.4     19
# 1.0     16
# 2.2     14
# 1.9     13
# 2.0     12
# 1.7      8
# 1.8      8
# 2.1      8
# 1.6      4
# 1.4      3
# 1.5      3
# 1.2      1
# Name: Rating, dtype: int64

# %%
##Plot a bar plot of Content Rating vs Average Rating
gplay.groupby(["Content Rating"])["Rating"].mean().plot.bar()
# Out:
# <Axes: xlabel='Content Rating'>

# %%
##Plot the bar plot again with Median Rating
gplay.groupby(["Content Rating"])["Rating"].median().plot.bar()
plt.show()

# %%
# ?sns.barplot

# %%
##Plot the above bar plot using the estimator parameter
sns.barplot(data=gplay, x="Content Rating", y="Rating", estimator= np.median)
plt.show()

# %%
##Plot the bar plot with only the 5th percentile of Ratings
sns.barplot(data=gplay, x="Content Rating", y="Rating", estimator=lambda x: np.quantile(x,0.05))
plt.show()

# %%
##Question - Plot the bar plot with the minimum Rating
sns.barplot(data=gplay, x="Content Rating", y="Rating", estimator= np.min)
plt.show()

# %% [markdown]
# __Box Plots Revisited__
#
# - Apart from outlier analysis, box plots are great at comparing the spread and analysing a numerical variable across several categories
# - Here you'll be using **sns.boxplot()** function to plot the visualisation. Check out its documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# ?sns.boxplot

# %%
##Plot a box plot of Rating vs Content Rating
sns.boxplot(x=gplay["Content Rating"], y=gplay["Rating"])
plt.show()

# %%
##Question - Plot a box plot for the Rating column only
sns.boxplot(gplay.Rating)
plt.show()

# %%
gplay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8620 entries, 0 to 8619
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8620 non-null   object
#  1   Category        8620 non-null   object
#  2   Rating          8620 non-null   float64
#  3   Reviews         8620 non-null   int32
#  4   Size            8620 non-null   float64
#  5   Installs        8620 non-null   float64
#  6   Type            8620 non-null   object
#  7   Price           8620 non-null   float64
#  8   Content Rating  8620 non-null   object
#  9   Genres          8620 non-null   object
#  10  Last Updated    8620 non-null   object
#  11  Current Ver     8620 non-null   object
#  12  Android Ver     8620 non-null   object
# dtypes: float64(4), int32(1), object(8)
# memory usage: 841.9+ KB

# %%
gplay.Genres.value_counts()
# Out:
# Tools                     694
# Entertainment             508
# Education                 464
# Medical                   344
# Finance                   315
#                          ...
# Arcade;Pretend Play         1
# Card;Brain Games            1
# Lifestyle;Pretend Play      1
# Comics;Creativity           1
# Strategy;Creativity         1
# Name: Genres, Length: 115, dtype: int64

# %%
gplay[gplay["Genres"].isin(["Tools","Entertainment","Education", "Medical"])]
# Out:
#                                                     App   Category  Rating  \
# 589                                                 TED  EDUCATION     4.6
# 590   English Communication - Learn English for Chin...  EDUCATION     4.7
# 591                                        Khan Academy  EDUCATION     4.6
# 592                          Learn English with Wlingua  EDUCATION     4.7
# 594                             Learn Spanish - Español  EDUCATION     4.7
# ...                                                 ...        ...     ...
# 8607                                    Fr. Daoud Lamei     FAMILY     5.0
# 8609                                 Fr Agnel Ambarnath     FAMILY     4.2
# 8615                                      FR Calculator     FAMILY     4.0
# 8616                                   Sya9a Maroc - FR     FAMILY     4.5
# 8617                   Fr. Mike Schmitz Audio Teachings     FAMILY     5.0
#
# ...

# %%
##Question - Plot a box plot of Ratings across the 4 most popular Genres
Pop_gen=gplay[gplay["Genres"].isin(["Tools","Entertainment","Education", "Medical"])]
sns.boxplot(y=gplay["Rating"],x=Pop_gen["Genres"])
plt.show()

# %% [markdown]
# #### Heat Maps

# %% [markdown]
# Heat mapsutilise the concept of using colours and colour intensities to visualise a range of values. You must have seen heat maps in cricket or football broadcasts on television to denote the players’ areas of strength and weakness.

# %% [markdown]
# ![HeatMap](images\heatmap1.png)

# %% [markdown]
# - In python, you can create a heat map whenever you have a rectangular grid or table of numbers analysing any two features

# %% [markdown]
# ![heatmap2](images\heatmap2.png)

# %% [markdown]
# - You'll be using **sns.heatmap()** to plot the visualisation. Checkout its official documentation :https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
# ?pd.qcut

# %%
##Ratings vs Size vs Content Rating

##Prepare buckets for the Size column using pd.qcut
gplay["sizebucket"]=pd.qcut(gplay.Size, [0, 0.2, 0.4, 0.6, 0.8, 1], ["VL","LW","M","H", "VH"])

# %%
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000.0  Free    0.0       Everyone
# 1      967  14000.0    500000.0  Free    0.0       Everyone
# 2    87510   8700.0   5000000.0  Free    0.0       Everyone
# 3   215644  25000.0  50000000.0  Free    0.0           Teen
# 4      967   2800.0    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# ?pd.pivot_table

# %%
##Create a pivot table for Size_buckets and Content Rating with values set to Rating
pd.pivot_table(data= gplay, index= "Content Rating", columns=gplay["sizebucket"], values="Rating")
# Out:
# sizebucket            VL        LW         M         H        VH
# Content Rating
# Everyone        4.117536  4.158405  4.215784  4.170799  4.187302
# Everyone 10+    4.189474  4.207407  4.238318  4.193443  4.217073
# Mature 17+      3.978947  4.124211  4.021705  4.155172  4.193814
# Teen            4.184848  4.233094  4.143310  4.198131  4.246154

# %%
##Change the aggregation to median
pd.pivot_table(data= gplay, index= "Content Rating", columns=gplay["sizebucket"], values="Rating", aggfunc= np.median)
# Out:
# sizebucket        VL   LW    M    H   VH
# Content Rating
# Everyone        4.20  4.3  4.3  4.3  4.3
# Everyone 10+    4.10  4.3  4.3  4.3  4.3
# Mature 17+      4.25  4.2  4.1  4.1  4.2
# Teen            4.20  4.3  4.2  4.2  4.3

# %%
##Change the aggregation to 20th percentile
pd.pivot_table(data=gplay, index="Content Rating", columns=gplay["sizebucket"], values="Rating", aggfunc=lambda x: np.quantile(x,0.2))
# Out:
# sizebucket        VL    LW    M    H   VH
# Content Rating
# Everyone        3.80  3.80  4.0  3.8  3.9
# Everyone 10+    3.86  3.92  4.1  4.0  4.0
# Mature 17+      3.30  3.68  3.7  3.9  4.0
# Teen            3.80  3.90  3.9  4.0  4.0

# %%
##Store the pivot table in a separate variable
res= pd.pivot_table(data=gplay, index="Content Rating", columns=gplay["sizebucket"], values="Rating", aggfunc=lambda x: np.quantile(x,0.2))

# %%
##Plot a heat map
sns.heatmap(res)
plt.show()

# %%
##Apply customisations
sns.heatmap(res, annot=True, cmap= "Greens")
plt.show()

# %%
gplay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8620 entries, 0 to 8619
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8620 non-null   object
#  1   Category        8620 non-null   object
#  2   Rating          8620 non-null   float64
#  3   Reviews         8620 non-null   int32
#  4   Size            8620 non-null   float64
#  5   Installs        8620 non-null   float64
#  6   Type            8620 non-null   object
#  7   Price           8620 non-null   float64
#  8   Content Rating  8620 non-null   object
#  9   Genres          8620 non-null   object
#  10  Last Updated    8620 non-null   object
#  11  Current Ver     8620 non-null   object
#  12  Android Ver     8620 non-null   object
#  13  sizebucket      8620 non-null   category
# dtypes: category(1), float64(4), int32(1), object(8)
# memory usage: 850.5+ KB

# %%
##Question - Replace Content Rating with Review_buckets in the above heat map
##Keep the aggregation at minimum value for Rating
gplay["Review_bucket"]= pd.qcut(gplay["Reviews"], [0,0.2,0.4,0.6,0.8,1], ["vl", "l","m","h","vh"])

# %%
pd.pivot_table(data=gplay, index=gplay["Review_bucket"], columns= gplay["sizebucket"], values= "Rating", aggfunc= lambda x: np.quantile(x,0.05))
# Out:
# sizebucket       VL     LW     M      H   VH
# Review_bucket
# vl             2.70  2.375  2.41  2.065  2.4
# l              2.80  2.800  3.00  2.835  2.8
# m              3.21  3.300  3.29  3.500  3.4
# h              3.80  3.600  3.70  3.600  3.7
# vh             3.75  3.900  4.00  3.900  3.9

# %%
result= pd.pivot_table(data=gplay, index=gplay["Review_bucket"], columns= gplay["sizebucket"], values= "Rating", aggfunc= lambda x: np.quantile(x,0.05))

# %%
sns.heatmap(result, annot= True, cmap= "Greens")
plt.show()

# %% [markdown]
# ### Session 3: Additional Visualisations

# %% [markdown]
# #### Line Plots

# %% [markdown]
# - A line plot tries to observe trends using time dependent data.
# -  For this part, you'll be using **pd.to_datetime()** function. Check out its documentation:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html

# %%
gplay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8620 entries, 0 to 8619
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8620 non-null   object
#  1   Category        8620 non-null   object
#  2   Rating          8620 non-null   float64
#  3   Reviews         8620 non-null   int32
#  4   Size            8620 non-null   float64
#  5   Installs        8620 non-null   float64
#  6   Type            8620 non-null   object
#  7   Price           8620 non-null   float64
#  8   Content Rating  8620 non-null   object
#  9   Genres          8620 non-null   object
#  10  Last Updated    8620 non-null   object
#  11  Current Ver     8620 non-null   object
#  12  Android Ver     8620 non-null   object
#  13  sizebucket      8620 non-null   category
#  14  Review_bucket   8620 non-null   category
# dtypes: category(2), float64(4), int32(1), object(8)
# memory usage: 859.2+ KB

# %%
gplay["Last Updated"].value_counts()
# Out:
# August 3, 2018       245
# August 2, 2018       236
# August 1, 2018       224
# July 31, 2018        202
# July 30, 2018        170
#                     ...
# April 4, 2014          1
# June 29, 2017          1
# April 14, 2015         1
# December 24, 2016      1
# March 23, 2014         1
# Name: Last Updated, Length: 1296, dtype: int64

# %%
## Extract the month from the Last Updated Date
gplay["Updated_month"]= pd.to_datetime(gplay["Last Updated"]).dt.month

# %%
## Find the average Rating across all the months
gplay.groupby(gplay["Last Updated"])["Rating"].mean()
# Out:
# Last Updated
# April 1, 2016        4.00
# April 1, 2017        4.20
# April 1, 2018        4.54
# April 10, 2013       4.60
# April 10, 2014       4.40
#                      ...
# September 8, 2015    4.10
# September 8, 2016    4.15
# September 8, 2017    4.06
# September 9, 2015    3.70
# September 9, 2016    4.15
# Name: Rating, Length: 1296, dtype: float64

# %%
## Plot a line graph
plt.figure(figsize=[12,5])
gplay.groupby(gplay["Updated_month"])["Rating"].mean().plot()
plt.show()

# %% [markdown]
# #### Stacked Bar Charts

# %% [markdown]
# - A stacked bar chart breaks down each bar of the bar chart on the basis of a different category
# - For example, for the Campaign Response bar chart you saw earlier, the stacked bar chart is also showing the Gender bifurcation as well

# %% [markdown]
# ![Stacked](images\stacked.png)

# %%
## Create a pivot table for Content Rating and updated Month with the values set to Installs
pd.pivot_table(data= gplay, columns= "Content Rating", index= "Updated_month", values="Installs")
# Out:
# Content Rating      Everyone  Everyone 10+    Mature 17+          Teen
# Updated_month
# 1               2.737833e+06  4.386750e+06  5.706594e+05  1.635519e+06
# 2               1.540599e+06  1.238812e+06  8.681000e+05  1.277345e+06
# 3               1.524924e+06  1.595922e+06  6.074067e+05  1.597006e+06
# 4               2.433428e+06  2.118182e+06  2.767895e+05  3.367071e+06
# 5               2.781865e+06  4.376796e+06  2.180004e+06  2.502341e+06
# 6               2.879206e+06  6.907111e+06  2.641040e+06  3.646637e+06
# 7               4.066515e+06  4.755792e+06  2.542375e+06  6.456999e+06
# 8               6.171637e+06  3.721052e+06  4.012586e+06  8.115198e+06
# 9               1.251637e+06  1.466535e+06  3.668350e+05  8.993240e+05
# 10              9.746403e+05  2.887625e+06  4.514286e+05  1.342036e+06
# 11              2.414767e+06  1.005167e+07  1.783500e+05  1.157819e+06
# 12              2.069729e+06  9.344444e+05  1.178191e+06  1.477346e+06

# %%
##Store the table in a separate variable
monthly=pd.pivot_table(data=gplay, columns= "Content Rating", index= "Updated_month", values= "Installs")

# %%
gplay["Content Rating"].value_counts()
# Out:
# Everyone        6938
# Teen             928
# Mature 17+       417
# Everyone 10+     337
# Name: Content Rating, dtype: int64

# %%
##Plot the stacked bar chart.
monthly.plot(kind="bar", stacked= True, figsize=[10,6])
plt.show()

# %%
##Plot the stacked bar chart again wrt to the proportions.
monthly[["Everyone",	"Everyone 10+",	"Mature 17+",	"Teen"]].apply(lambda x: x/x.sum(),axis=1)
# Out:
# Content Rating  Everyone  Everyone 10+  Mature 17+      Teen
# Updated_month
# 1               0.293420      0.470139    0.061159  0.175282
# 2               0.312821      0.251543    0.176269  0.259367
# 3               0.286357      0.299689    0.114061  0.299893
# 4               0.296924      0.258458    0.033773  0.410845
# 5               0.234935      0.369630    0.184106  0.211328
# 6               0.179122      0.429707    0.164305  0.226866
# 7               0.228178      0.266854    0.142656  0.362311
# 8               0.280268      0.168981    0.182221  0.368530
# 9               0.314140      0.368076    0.092069  0.225715
# 10              0.172328      0.510566    0.079818  0.237288
# 11              0.174950      0.728244    0.012921  0.083884
# 12              0.365695      0.165105    0.208172  0.261029

# %%
monthly.plot(kind="bar", stacked= True, figsize=[10,5])
plt.show()

# %% [markdown]
# #### Plotly

# %% [markdown]
# Plotly is a Python library used for creating interactive visual charts. You can take a look at how you can use it to create aesthetic looking plots with a lot of user-friendly functionalities like hover, zoom, etc.

# %% [markdown]
# Check out this link for installation and documentation:https://plot.ly/python/getting-started/

# %%
#Install plotly
# !pip install plotly

# %%
#Take the table you want to plot in a separate variable
tab=gplay.groupby(["Updated_month"])[["Rating"]].mean()

# %%
tab.reset_index(inplace= True)

# %%
#Import the plotly libraries
import plotly.express as px

# %%
#Prepare the plot
fig= px.line(tab, x="Updated_month", y="Rating", title="Monthly Average Rating")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
